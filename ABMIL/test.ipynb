# %%
import torch
import timm
import torch.nn as nn
DROP_RATE = 0.3
# EfficientNet_b2 모델을 불러오고, 사전 훈련된 가중치를 사용합니다.
model = timm.create_model('efficientnet_b3', pretrained=True, num_classes=1, drop_rate=DROP_RATE)
# model = timm.create_model('densenet121', pretrained=True, num_classes=1, drop_rate=DROP_RATE)

model = timm.create_model('resnet18', pretrained=True, num_classes=1, drop_rate=DROP_RATE)
# 여기서 모델을 필요에 따라 수정하거나, 추가 설정을 할 수 있습니다.
# 예를 들어, 마지막 레이어를 교체하거나, dropout 비율을 조정하는 등의 작업을 할 수 있습니다.


def print_trainable_parameters(model):
    trainable_params = 0
    all_param = 0
    for param in model.parameters():
        all_param += param.numel()
        if param.requires_grad: # True이면 learnable parameter에 추가
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param:.2f}"
    )
    return trainable_params, all_param

print_trainable_parameters,basic_model_params_num =  print_trainable_parameters(model)

print(model.fc.in_features)
print(model.fc)

model.fc = nn.BatchNorm1d(model.fc.in_features)
# model.classifier = nn.Sequential(
#     nn.Linear(model.classifier.in_features, 512),
#     nn.BatchNorm1d(512),
# )
cls_layer = nn.Sequential(
    nn.Linear(512,1),
    nn.Sigmoid(),
)

# x = torch.randn(1,3,224,224)
# z = model(x)
# y = classifier(z)
y.shape,z.shape
# model.classifier
# model.fc
# Out:
# trainable params: 11177025 || all params: 11177025 || trainable%: 100.00
# 512
# Linear(in_features=512, out_features=1, bias=True)
# (torch.Size([1, 512]), torch.Size([1, 512]))

# %%
import torch
import timm
import torch.nn as nn

model = timm.create_model('efficientnet_b5', pretrained=True, num_classes=512)
model.classifier = nn.Sequential(
    nn.Linear(model.classifier.in_features, 512),
    nn.BatchNorm1d(512),
)

classifier = nn.Sequential(
    nn.Linear(512, 1),
    nn.Sigmoid()
)

# %%
import torchvision.models as models
# resnet18 = models.resnet18(pretrained=True)
# alexnet = models.alexnet(pretrained=True)
# squeezenet = models.squeezenet1_0(pretrained=True)
# vgg16 = models.vgg16(pretrained=True)
densenet = models.densenet161(pretrained=True)

# print_trainable_parameters(densenet)
densenet
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
# ...
